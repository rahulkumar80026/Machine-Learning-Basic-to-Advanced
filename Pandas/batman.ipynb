# %%
import numpy as np
import pandas as pd

# %%
# using list
student_data =[
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,50,2]
]

pd.DataFrame(student_data,columns=['iq','marks','pakage'])
# Out:
#     iq  marks  pakage
# 0  100     80      10
# 1   90     70       7
# 2  120    100      14
# 3   80     50       2

# %%
# using dicts

student_dict ={
    'name':['Alice','Bob','Charlie','David','Eva','Frank'],
    'iq':[100,90,120,80,0,0],
    'marks':[80,70,100,50,0,0],
    'pakage':[10,7,14,2,0,0]
}

students=pd.DataFrame(student_dict)
students.set_index('name', inplace=True)
students
# Out:
#           iq  marks  pakage
# name
# Alice    100     80      10
# Bob       90     70       7
# Charlie  120    100      14
# David     80     50       2
# Eva        0      0       0
# Frank      0      0       0

# %%
# using read_csv
movies=pd.read_csv('movies.csv')
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl=pd.read_csv('ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# DataFrame Attributes and Methods

# %%
# shape
movies.shape
ipl.shape
# Out:
# (950, 20)

# %%
# dtype
movies.dtypes
ipl.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
# index
movies.index
ipl.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
# columns
movies.columns
ipl.columns
students.columns
# Out:
# Index(['iq', 'marks', 'pakage'], dtype='object')

# %%
# value
movies.values
ipl.values
# students.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
# head and tail
movies.head()
movies.tail()
ipl.head()
ipl.tail()
# Out:
#          ID        City        Date   Season MatchNumber  \
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# ...

# %%
# sample
movies.sample(5)
ipl.sample(5)
# Out:
#           ID        City        Date   Season MatchNumber  \
# 286  1136589   Bengaluru  2018-04-29     2018          29
# 775   419165      Mumbai  2010-04-25  2009/10       Final
# 745   501229       Kochi  2011-04-27     2011          32
# 900   336002   Hyderabad  2008-05-25  2007/08          51
# 394   980977  Chandigarh  2016-05-09     2016          39
#
#                            Team1                        Team2  \
# 286  Royal Challengers Bangalore        Kolkata Knight Riders
# 775          Chennai Super Kings               Mumbai Indians
# 745         Kochi Tuskers Kerala              Deccan Chargers
# 900              Deccan Chargers  Royal Challengers Bangalore
# 394              Kings XI Punjab  Royal Challengers Bangalore
#
#                                                  Venue             TossWinner  \
# 286                              M.Chinnaswamy Stadium  Kolkata Knight Riders
# 775                         Dr DY Patil Sports Academy    Chennai Super Kings
# ...

# %%
# info
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# describe
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
# isnull
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
ipl.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
# duplicates
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
ipl.duplicated().sum()
# Out:
# np.int64(0)

# %%
students.duplicated().sum()
# Out:
# np.int64(1)

# %%
# rename
students.rename(columns={'iq':'intelligence quotient','marks':'exam marks','pakage':'package'}, inplace=True)
students
# Out:
#          intelligence quotient  exam marks  package
# name
# Alice                      100          80       10
# Bob                         90          70        7
# Charlie                    120         100       14
# David                       80          50        2
# Eva                          0           0        0
# Frank                        0           0        0

# %% [markdown]
# Math Methods

# %%
# sum method apply all in columns it try to sum int and also str
movies.sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 2
#       1 # sum method apply all in columns it try to sum int and also str
# ----> 2 movies.sum()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:11677, in DataFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11668 @doc(make_doc("sum", ndim=2))
#   11669 def sum(
#   11670     self,
#    (...)  11675     **kwargs,
#   11676 ):
# > 11677     result = super().sum(axis, skipna, numeric_only, min_count, **kwargs)
#   11678     return result.__finalize__(self, method="sum")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py:12525, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12517 def sum(
#   12518     self,
#   12519     axis: Axis | None = 0,
#    (...)  12523     **kwargs,
#   12524 ):
# ...

# %%
students.sum()
# Out:
# intelligence quotient    390
# exam marks               300
# package                   33
# dtype: int64

# %%
students.sum(axis=1) # row wise
# Out:
# 0    190
# 1    167
# 2    234
# 3    132
# 4      0
# 5      0
# dtype: int64

# %%
students.mean(axis=1) # row wise
# Out:
# 0    63.333333
# 1    55.666667
# 2    78.000000
# 3    44.000000
# 4     0.000000
# 5     0.000000
# dtype: float64

# %%
students.median()
# Out:
# intelligence quotient    85.0
# exam marks               60.0
# package                   4.5
# dtype: float64

# %%
students.median(axis=1)
# Out:
# 0     80.0
# 1     70.0
# 2    100.0
# 3     50.0
# 4      0.0
# 5      0.0
# dtype: float64

# %% [markdown]
# Selecting rows from a DataFrame
#
# . ilo - searches using index position
#
# . loc - searches using index labels

# %% [markdown]
# Selecting Columns from dataframe

# %%
# single column
movies['title_x']
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object

# %%
ipl['Venue']
# Out:
# 0                Narendra Modi Stadium, Ahmedabad
# 1                Narendra Modi Stadium, Ahmedabad
# 2                           Eden Gardens, Kolkata
# 3                           Eden Gardens, Kolkata
# 4                        Wankhede Stadium, Mumbai
#                           ...
# 945                                  Eden Gardens
# 946                              Wankhede Stadium
# 947                              Feroz Shah Kotla
# 948    Punjab Cricket Association Stadium, Mohali
# 949                         M Chinnaswamy Stadium
# Name: Venue, Length: 950, dtype: object

# %%
# multiple cols
movies[['title_x','year_of_release','actors']]
# Out:
#                                    title_x  year_of_release  \
# 0                 Uri: The Surgical Strike             2019
# 1                            Battalion 609             2019
# 2     The Accidental Prime Minister (film)             2019
# 3                          Why Cheat India             2019
# 4                          Evening Shadows             2018
# ...                                    ...              ...
# 1624                 Tera Mera Saath Rahen             2001
# 1625                  Yeh Zindagi Ka Safar             2001
# 1626                       Sabse Bada Sukh             2018
# 1627                                 Daaka             2019
# 1628                              Humsafar             2011
#
#                                                  actors
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# ...

# %%
# single row
movies.iloc[1]
# Out:
# title_x                                                 Battalion 609
# imdb_id                                                     tt9472208
# poster_path                                                       NaN
# wiki_link                 https://en.wikipedia.org/wiki/Battalion_609
# title_y                                                 Battalion 609
# original_title                                          Battalion 609
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           131
# genres                                                            War
# imdb_rating                                                       4.1
# imdb_votes                                                         73
# story               The story revolves around a cricket match betw...
# ...

# %%
# multiple rows
movies.iloc[0:15:2]
# Out:
#                                  title_x    imdb_id  \
# 0               Uri: The Surgical Strike  tt8291224
# 2   The Accidental Prime Minister (film)  tt6986710
# 4                        Evening Shadows  tt6028796
# 6                          Fraud Saiyaan  tt5013008
# 8       Manikarnika: The Queen of Jhansi  tt6903440
# 10                                Amavas  tt8396186
# 12                             Hum Chaar  tt9319812
# 14                            Sonchiriya  tt8108200
#
#                                           poster_path  \
# 0   https://upload.wikimedia.org/wikipedia/en/thum...
# 2   https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                 NaN
# 6   https://upload.wikimedia.org/wikipedia/en/thum...
# 8   https://upload.wikimedia.org/wikipedia/en/thum...
# 10  https://upload.wikimedia.org/wikipedia/en/thum...
# 12  https://upload.wikimedia.org/wikipedia/en/thum...
# 14  https://upload.wikimedia.org/wikipedia/en/thum...
#
# ...

# %%
# fancy indexing
movies.iloc[[0,4,5]]
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 4           Evening Shadows  tt6028796
# 5               Soni (film)  tt6078866
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
# 5          https://en.wikipedia.org/wiki/Soni_(film)
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 4           Evening Shadows           Evening Shadows         0
# 5                      Soni                      Soni         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# ...

# %%
# loc
students
# Out:
#          intelligence quotient  exam marks  package
# name
# Alice                      100          80       10
# Bob                         90          70        7
# Charlie                    120         100       14
# David                       80          50        2
# Eva                          0           0        0
# Frank                        0           0        0

# %%
students.loc['Alice']
# Out:
# intelligence quotient    100
# exam marks                80
# package                   10
# Name: Alice, dtype: int64

# %%
students.loc['Alice':'Eva':2]
# Out:
#          intelligence quotient  exam marks  package
# name
# Alice                      100          80       10
# Charlie                    120         100       14
# Eva                          0           0        0

# %%
students.loc[['Alice','Eva','Charlie']]
# Out:
#          intelligence quotient  exam marks  package
# name
# Alice                      100          80       10
# Eva                          0           0        0
# Charlie                    120         100       14

# %%
students.iloc[0:5:2]
# Out:
#          intelligence quotient  exam marks  package
# name
# Alice                      100          80       10
# Charlie                    120         100       14
# Eva                          0           0        0

# %%
students.iloc[[0, 5, 2]]
# Out:
#          intelligence quotient  exam marks  package
# name
# Alice                      100          80       10
# Frank                        0           0        0
# Charlie                    120         100       14

# %% [markdown]
# Selecting both rows and cols

# %%
movies.iloc[]
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...
